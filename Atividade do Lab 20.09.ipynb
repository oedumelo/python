# %%
idade1 = 18
idade2 = 27

# %%
idade1 + idade2
# Out:
# 45

# %%
soma = idade1 + idade2

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %%
L = list()

# %%
L = [14, 15, 16]

# %%
print(L)
# Out:
# [14, 15, 16]

# %%
L[0]
# Out:
# 14

# %%
L[0] = 12

# %%
L[0]
# Out:
# 12

# %%
lista2 = L

# %%
print(L == lista2)
# Out:
# True

# %%
print(L is lista2)
# Out:
# True

# %%
lista2[0] = 1

# %%
L
# Out:
# [1, 15, 16]

# %%
print(L)
print(lista2)
# Out:
# [1, 15, 16]
# [1, 15, 16]

# %%
lista3 = lista2.copy()

# %%
lista4 = lista2[:]

# %% [markdown]
# FATIAMENTO

# %%
nova_lista = ["a", "b", "c", "d", "e", "f"]

# %%
nova_lista[1:3]
# Out:
# ['b', 'c']

# %%
nova_lista[0:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
nova_lista[:4]
# Out:
# ['a', 'b', 'c', 'd']

# %%
nova_lista[:]
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']
